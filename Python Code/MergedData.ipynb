# %%
# Import our dependencies
import pandas as pd
import numpy as np
import pathlib

# %%
csv_dir = pathlib.Path.cwd().parent / 'CSV files' # can join path elements with / operator

acquisition_df = pd.read_csv(csv_dir / 'Final Project Data.csv', sep=",")
acquisition_df = acquisition_df.rename(columns = {'Loan Identifier':'loan identifier'})
acquisition_df = acquisition_df.drop(['Co-borrower Credit Score at Origination', 'Mortgage Insurance Type'], axis = 1)
acquisition_df.head()
# Out:
#    loan identifier Origination Channel  \
# 0     100000913397                   C
# 1     100017539727                   B
# 2     100018053040                   R
# 3     100019764317                   C
# 4     100019765730                   B
#
#                                          Seller Name  Original Interest Rate  \
# 0          JPMORGAN CHASE BANK, NATIONAL ASSOCIATION                       6
# 1                                              OTHER                       5
# 2          JPMORGAN CHASE BANK, NATIONAL ASSOCIATION                       5
# 3                             WELLS FARGO BANK, N.A.                       5
# 4  UNITED SHORE FINANCIAL SERVICES, LLC DBA UNITE...                       4
#
#    Original UPB  Original Loan Term Origination Date First Payment Date  \
# 0        324000                 360       2018-09-01         2018-11-01
# 1        307000                 360       2018-12-01         2019-02-01
# 2        256000                 360       2018-11-01         2019-01-01
# 3        248000                 360       2018-12-01         2019-02-01
# 4        490000                 360       2019-03-01         2019-05-01
#
#    Original Loan-to-value (LTV)  Original Combined Loan-to-value (CLTV)  ...  \
# 0                            80                                      80  ...
# 1                            90                                      90  ...
# 2                            90                                      90  ...
# 3                            90                                      90  ...
# 4                            67                                      67  ...
#
#    First Time Home Buyer Indicator  Loan Purpose   Property Type  \
# 0                                N              C             PU
# 1                                N              P             PU
# 2                                N              P             SF
# 3                                Y              P             SF
# 4                                Y              P             CO
#
#   Number of Units Occupancy Type Property State  Zip Code Short  \
# 0               1              P             CA             925
# 1               1              P             TX             770
# 2               1              S             NC             286
# 3               1              P             IL             600
# 4               1              P             CA             945
#
#   Primary Mortgage Insurance Percent  Product Type  \
# 0                                 NaN          FRM
# 1                                25.0          FRM
# 2                                25.0          FRM
# 3                                25.0          FRM
# 4                                 NaN          FRM
#
#    Relocation Mortgage Indicator
# 0                              N
# 1                              N
# 2                              N
# 3                              N
# 4                              N
#
# [5 rows x 23 columns]

# %%
#performance_df = pd.read_csv(csv_dir / 'cleaned_Performance.csv', sep=",")
#performance_df.head()
# This 'cleaned_Performance.csv' file, somewhere in the pipeline, lost most of its observations.
# I think they got cut off when importing the .txt file into Excel, then converting it to .csv.
# To avoid this, I think I'll copy the code for cleaning performance in this notebook.
# So the performance data can go from .txt into the mergedData without any .csv conversion in the middle.

performance_df = pd.read_csv(csv_dir / 'cleaned_Performance_full.csv', sep=",")
performance_df.head()
# Out:
#    loan identifier monthly reporting period  current interest rate  loan age  \
# 0     100000913397               2019-01-01                   5.88         3
# 1     100000913397               2019-02-01                   5.88         4
# 2     100000913397               2019-03-01                   5.88         5
# 3     100000913397               2019-04-01                   5.88         6
# 4     100000913397               2019-05-01                   5.88         7
#
#    remaining months to legal maturity  adjusted months to maturity  \
# 0                                 357                        357.0
# 1                                 356                        356.0
# 2                                 355                        355.0
# 3                                 354                        354.0
# 4                                 353                        353.0
#
#   maturity date    MSA current loan delinquency status modification flag
# 0    2048-10-01  40140                               0                 N
# 1    2048-10-01  40140                               0                 N
# 2    2048-10-01  40140                               0                 N
# 3    2048-10-01  40140                               0                 N
# 4    2048-10-01  40140                               0                 N

# %%
#perf_col_names = ['']
#raw_perf_df = pd.read_csv("Performance_2019Q1.csv", sep="|", header=None, names=perf_col_names)
#raw_perf_df.head()

# %%
# Creates a subset dataframe containing all rows from performance where current loan delinquency status != 0.
performance_df["current loan delinquency status"].unique()
delinquency_df = performance_df[performance_df["current loan delinquency status"] != '0']
# This is a start, but the resulting merge has some duplicate loan identifiers and null entries for acquisition rows where none of their performance rows are in the above table.

# %%
full_perf_df = performance_df.sort_values("monthly reporting period").groupby(by = "loan identifier").tail(1)
full_perf_df.head()
#full_perf_df.count
# Out:
#          loan identifier monthly reporting period  current interest rate  \
# 1004059     391757295836               2019-02-01                   4.88
# 209046      160527809683               2019-02-01                   5.25
# 16118       104765459314               2019-02-01                   5.50
# 91683       126533834704               2019-02-01                   5.63
# 15815       104640949538               2019-02-01                   5.75
#
#          loan age  remaining months to legal maturity  \
# 1004059         1                                 359
# 209046          2                                 358
# 16118           2                                 358
# 91683           2                                 358
# 15815           1                                 359
#
#          adjusted months to maturity maturity date    MSA  \
# 1004059                          0.0    2049-01-01  35620
# 209046                           0.0    2048-12-01  41620
# 16118                            0.0    2048-12-01  31180
# 91683                            0.0    2048-12-01  31080
# 15815                            0.0    2049-01-01  41860
#
#         current loan delinquency status modification flag
# 1004059                               X                 N
# 209046                                X                 N
# 16118                                 X                 N
# 91683                                 X                 N
# 15815                                 X                 N

# %%
# This is a new column, meant to be the target variable, calculated from if "current loan delinquency status" != '0'
full_perf_df["delinquency"] = full_perf_df["current loan delinquency status"] != '0'
full_perf_df.head()
# Out:
#          loan identifier monthly reporting period  current interest rate  \
# 1004059     391757295836               2019-02-01                   4.88
# 209046      160527809683               2019-02-01                   5.25
# 16118       104765459314               2019-02-01                   5.50
# 91683       126533834704               2019-02-01                   5.63
# 15815       104640949538               2019-02-01                   5.75
#
#          loan age  remaining months to legal maturity  \
# 1004059         1                                 359
# 209046          2                                 358
# 16118           2                                 358
# 91683           2                                 358
# 15815           1                                 359
#
#          adjusted months to maturity maturity date    MSA  \
# 1004059                          0.0    2049-01-01  35620
# 209046                           0.0    2048-12-01  41620
# 16118                            0.0    2048-12-01  31180
# 91683                            0.0    2048-12-01  31080
# 15815                            0.0    2049-01-01  41860
#
#         current loan delinquency status modification flag  delinquency
# 1004059                               X                 N         True
# 209046                                X                 N         True
# 16118                                 X                 N         True
# 91683                                 X                 N         True
# 15815                                 X                 N         True

# %%
# Save the transformed performance dataframe into a csv file.
full_perf_df.to_csv(csv_dir / 'full_perf_df.csv', index = False)

# %%
merge_df = acquisition_df.merge(full_perf_df, on="loan identifier", how="left")
merge_df.head()
# Out:
#    loan identifier Origination Channel  \
# 0     100000913397                   C
# 1     100017539727                   B
# 2     100018053040                   R
# 3     100019764317                   C
# 4     100019765730                   B
#
#                                          Seller Name  Original Interest Rate  \
# 0          JPMORGAN CHASE BANK, NATIONAL ASSOCIATION                       6
# 1                                              OTHER                       5
# 2          JPMORGAN CHASE BANK, NATIONAL ASSOCIATION                       5
# 3                             WELLS FARGO BANK, N.A.                       5
# 4  UNITED SHORE FINANCIAL SERVICES, LLC DBA UNITE...                       4
#
#    Original UPB  Original Loan Term Origination Date First Payment Date  \
# 0        324000                 360       2018-09-01         2018-11-01
# 1        307000                 360       2018-12-01         2019-02-01
# 2        256000                 360       2018-11-01         2019-01-01
# 3        248000                 360       2018-12-01         2019-02-01
# 4        490000                 360       2019-03-01         2019-05-01
#
#    Original Loan-to-value (LTV)  Original Combined Loan-to-value (CLTV)  ...  \
# 0                            80                                      80  ...
# 1                            90                                      90  ...
# 2                            90                                      90  ...
# 3                            90                                      90  ...
# 4                            67                                      67  ...
#
#    monthly reporting period  current interest rate  loan age  \
# 0                2019-12-01                   5.88      14.0
# 1                2019-12-01                   4.75      11.0
# 2                2019-12-01                   4.88      12.0
# 3                2019-10-01                   4.88       9.0
# 4                2019-12-01                   4.25       8.0
#
#   remaining months to legal maturity adjusted months to maturity  \
# 0                              346.0                       346.0
# 1                              349.0                       349.0
# 2                              348.0                       348.0
# 3                              351.0                         0.0
# 4                              352.0                       352.0
#
#   maturity date      MSA current loan delinquency status modification flag  \
# 0    2048-10-01  40140.0                               0                 N
# 1    2049-01-01  26420.0                               0                 N
# 2    2048-12-01      0.0                               0                 N
# 3    2049-01-01  16980.0                               X                 N
# 4    2049-04-01  41860.0                               0                 N
#
#    delinquency
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#
# [5 rows x 33 columns]

# %%
# Save the merged dataframe into a csv file.
merge_df.to_csv(csv_dir / 'mergedData.csv', index = False)

# %%
#merge_df.isnull().sum()
